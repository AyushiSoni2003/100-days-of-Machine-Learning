# %%
import pandas as pd

# %% [markdown]
# # Working With JSON

# %%
pd.read_json('Game_Of_Thrones.json')
# Out:
#            Game Of Thrones S01E01 Winter Is Coming.srt  \
# 1                                           Easy, boy.
# 10             Our orders were to track the wildlings.
# 100                       - Right. Give it here. - No!
# 101                               Put away your blade.
# 102  - I take orders from your father, not you. - P...
# ..                                                 ...
# 771                                                NaN
# 772                                                NaN
# 773                                                NaN
# 774                                                NaN
# 775                                                NaN
#
#     Game Of Thrones S01E02 The Kingsroad.srt  \
# 1                  You need to drink, child.
# 10         The Dothraki believe that one day
# 100                     Such a little thing.
# 101                 A bird without feathers.
# 102          They came to take his body away
# ...

# %% [markdown]
# ### Load From a URL

# %%
pd.read_json('https://www.kaggle.com/datasets/gunnvant/game-of-thrones-srt?select=season1.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pd.read_json('https://www.kaggle.com/datasets/gunnvant/game-of-thrones-srt?select=season1.json')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
# ...

# %% [markdown]
# # Working with SQL

# %% [markdown]
# ### Install mysql connector

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/11.9 MB 5.6 MB/s eta 0:00:02
#      ------- -------------------------------- 2.1/11.9 MB 5.3 MB/s eta 0:00:02
#      --------- ------------------------------ 2.9/11.9 MB 4.5 MB/s eta 0:00:02
#      ------------ --------------------------- 3.7/11.9 MB 4.4 MB/s eta 0:00:02
#      --------------- ------------------------ 4.7/11.9 MB 4.5 MB/s eta 0:00:02
#      ------------------- -------------------- 5.8/11.9 MB 4.6 MB/s eta 0:00:02
#      ---------------------- ----------------- 6.6/11.9 MB 4.6 MB/s eta 0:00:02
#      ------------------------- -------------- 7.6/11.9 MB 4.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 8.7/11.9 MB 4.6 MB/s eta 0:00:01
#      -------------------------------- ------- 9.7/11.9 MB 4.6 MB/s eta 0:00:01
#      ------------------------------------ --- 10.7/11.9 MB 4.7 MB/s eta 0:00:01
# ...

# %% [markdown]
# ### Install SQLAlchemy connector

# %%
pip install mysql-connector-python sqlalchemy
# Out:
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/16.4 MB 5.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.8/16.4 MB 5.0 MB/s eta 0:00:03
#    ------- -------------------------------- 2.9/16.4 MB 4.7 MB/s eta 0:00:03
#    --------- ------------------------------ 3.9/16.4 MB 4.7 MB/s eta 0:00:03
#    ------------ --------------------------- 5.0/16.4 MB 4.7 MB/s eta 0:00:03
#    -------------- ------------------------- 5.8/16.4 MB 4.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.1/16.4 MB 4.7 MB/s eta 0:00:02
#    ------------------- -------------------- 7.9/16.4 MB 4.8 MB/s eta 0:00:02
#    --------------------- ------------------ 8.7/16.4 MB 4.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/16.4 MB 4.5 MB/s eta 0:00:02
#    ------------------------ --------------- 10.2/16.4 MB 4.5 MB/s eta 0:00:02
# ...

# %%
import mysql.connector
import mysql.connector
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+mysqlconnector://root:@localhost/world")

# %%
df = pd.read_sql("SELECT * FROM countrylanguage" , con = engine)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\network.py:509, in MySQLTCPSocket.open_connection(self)
#     508     self.sock.settimeout(self._connection_timeout)
# --> 509     self.sock.connect(sockaddr)
#     510 except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
# ...

# %%
df.head
